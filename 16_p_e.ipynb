# %% [markdown]
# ## Annual mean precipitation and evaporation

# %%
import numpy as np
import xarray as xr

# %%
# Open annual mean precipitation and evaporation data
with xr.open_dataset('era_PE2010.nc') as ds:
    print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 240, latitude: 121, time: 1)
# Coordinates:
#   * longitude  (longitude) float32 0.0 1.5 3.0 4.5 ... 354.0 355.5 357.0 358.5
#   * latitude   (latitude) float32 90.0 88.5 87.0 85.5 ... -87.0 -88.5 -90.0
#   * time       (time) datetime64[ns] 2010-07-02T14:00:00
# Data variables:
#     e          (time, latitude, longitude) float64 ...
#     tp         (time, latitude, longitude) float64 ...
# Attributes:
#     Conventions:               CF-1.0
#     history:                   Mon Feb 10 18:52:10 2014: ncra output.nc ERA_E...
#     nco_openmp_thread_number:  1

# %%
# Plot evaporation
(ds.e*-4000).plot()   # m/4/day to mm/day

# %% [markdown]
# ### Exercise
# Plot annual mean precipitation (mm/day).

# %% [markdown]
# ### Exercise
# Plot annual mean precipitation minus evaporation (mm/day).

# %%
# Plot zonal mean of evaporation
(ds.e*-4000.).mean("longitude").plot()

# %% [markdown]
# ### Exercise
# Plot zonal mean of evaporation and precipitation (mm/day).
